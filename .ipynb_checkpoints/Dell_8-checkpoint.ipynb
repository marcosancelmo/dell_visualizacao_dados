# %% [raw]
# * Representar distribuições categóricas com gráfico de dispersão categórico;
# * Interpretar e criar gráficos de caixa para representar distribuições categóricas;
# * Interpretar e criar gráficos de violino para representar distribuições categóricas.

# %% [raw]
# Tópico 1 – Gráficos de dispersão categóricos
#
# OBJETIVOS:
# Aprender a criar gráficos de dispersão categóricos, utilizando a biblioteca seaborn;
# Aprender a criar gráficos de dispersão categóricos através da função stripplot();
# Aprender a criar gráficos de enxame através da função swarmplot().

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="darkgrid")

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.figure(figsize=(10,5))
plt.title('Idade de passageiros em cada classe')
sns.stripplot(x='class', y='age', data=titanic)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Idade de passageiros em cada classe')
sns.swarmplot(x="class", y="age", data=titanic)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Idade de passageiros em cada classe')
sns.swarmplot(x='class',y='age', hue='sex', data=titanic)
plt.show()

# %%
# Com FacetGrid usando a função catplot(), não permite alterar nada com matplot
sns.catplot(x="pclass", y="age", hue = 'sex', col = 'survived', kind = 'swarm', data=titanic)
# Out:
# C:\Users\User\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 10.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 7.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [raw]
# Tópico 2 – Gráficos de caixa
#
# OBJETIVOS:
# * Interpretar gráficos de caixa;
# * Aprender a criar gráficos de caixa, utilizando a biblioteca seaborn;
# * Aprender a criar gráficos de caixa para representar múltiplas distribuições categóricas.

# %%
plt.figure(figsize=(8,5))
plt.title("Idade de passageiros em cada classe")
sns.boxplot(x="class", y="age", data=titanic)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("Idade de passageiros em cada classe")
sns.boxplot(x="class", y="age", hue="sex", data=titanic)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title('Idade de passageiros em cada classe')
sns.boxenplot(x="class", y="age", hue = 'sex', data=titanic)
plt.show()

# %%
# Com FacetGrid usando a função catplot(), não permite alterar nada com matplot
sns.catplot(x="class", y="age", hue = 'sex', col = 'survived', kind = 'boxen', data=titanic)

# %% [raw]
# Tópico 3 – Gráficos de violino
#
# OBJETIVOS:
# * Interpretar gráficos de violino;
# * Aprender a criar gráficos de violino, utilizando a biblioteca seaborn;
# * Aprender a criar gráficos de violino para representar múltiplas distribuições categóricas.

# %%
plt.figure(figsize=(8,5))
plt.title('Idade de passageiros em cada classe')
sns.violinplot(x="class", y="age", data=titanic)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("Idade de passageiros em cada classe por sexo")
sns.violinplot(x="class", y="age",hue="sex", split=True, data=titanic)
plt.show()

# %%
# Com FacetGrid usando a função catplot(), não permite alterar nada com matplot
sns.catplot(x="class", y="age", hue = 'sex', col = 'survived', kind = 'violin', split = True, data=titanic)
